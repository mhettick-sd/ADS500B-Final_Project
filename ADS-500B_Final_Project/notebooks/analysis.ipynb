# %%
import numpy as np 
import pandas as pd 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\marin\\Documents\\ADS-500B_Final_Project\\notebooks'

# %%
houses = pd.read_csv("../data/raw/house_sales.csv")
